# %% [markdown]
# # EDA
# * 각 데이터 시트별로 살펴보겠습니다.

# %% [markdown]
# ## 모듈 로드

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import gc

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', 400)
pd.set_option('display.max_rows', 400)

# %% [markdown]
# ## 데이터 로드

# %%
path = './data/'

# %%
train = pd.read_csv(path + 'train.csv')
test = pd.read_csv(path + 'test.csv')
history = pd.read_csv(path + 'historical_transactions.csv')
new_history = pd.read_csv(path + 'new_merchant_transactions.csv')
# merchant = pd.read_csv(path + 'merchants.csv')

# %% [markdown]
# ## EDA with -33

# %% [markdown]
# ### -33 뽑기

# %%
card_id = train[train.target < - 30].card_id.values

# %%
train[train.target > 10]
# Out:
#        first_active_month          card_id  feature_1  feature_2  feature_3  \
# 4459              2017-05  C_ID_700c15a07d          3          2          1
# 4460              2017-01  C_ID_1c8a5b9d44          5          1          1
# 5252              2017-08  C_ID_1b28c8af6b          3          2          1
# 11921             2017-10  C_ID_648406c4c7          1          3          0
# 15360             2016-08  C_ID_a21da11a50          5          1          1
# 20798             2016-12  C_ID_48e3368518          5          2          1
# 26075             2017-01  C_ID_4e1cd1689e          5          1          1
# 28609             2017-11  C_ID_75bbf5a264          3          1          1
# 37303             2017-06  C_ID_6f979811eb          5          2          1
# 41325             2017-05  C_ID_a4e600deef          5          1          1
# 46765             2017-05  C_ID_a32b3ecb79          5          1          1
# ...

# %%
history.set_index('card_id', inplace=True)
new_history.set_index('card_id', inplace=True)

# %%
for v in card_id:
    print(v)
# Out:
# C_ID_8186f3fcc1
# C_ID_b9379a30ea
# C_ID_e9120f535c
# C_ID_65715cb80d
# C_ID_ae77d244b6
# C_ID_c4262c902e
# C_ID_6a2c823e5f
# C_ID_98e1cb10b6
# C_ID_eb8175721a
# C_ID_a2580006bf
# C_ID_2e49ece8b1
# C_ID_7efe2311b7
# C_ID_bae3e3f87c
# C_ID_e1844c986c
# C_ID_237b80978f
# C_ID_f96d46ff64
# C_ID_005799985c
# C_ID_962d44f420
# C_ID_d93d15ab8e
# C_ID_42d0ff3842
# C_ID_404d0c0488
# C_ID_5c99cb080c
# C_ID_1dc14ac66a
# C_ID_1e62ff489c
# C_ID_2d8cf677c6
# C_ID_b6f24b5e58
# C_ID_c0120bdf0b
# C_ID_19e7c999ad
# C_ID_efc4226180
# C_ID_4ae8415eae
# C_ID_804f9606eb
# C_ID_2fb29a568c
# C_ID_9152499bc1
# C_ID_5297dca7f5
# C_ID_ce58ebbf13
# C_ID_bcda954211
# C_ID_ba9f34429e
# C_ID_f6dbdc4008
# C_ID_5c3774c77b
# C_ID_9ea5498975
# C_ID_03e95ac152
# C_ID_977e2572aa
# C_ID_5526617082
# C_ID_4bdb2cebcc
# C_ID_6398d8edd9
# C_ID_b9dd1f51ae
# C_ID_852ed26419
# C_ID_332dee8351
# C_ID_4a97be79d1
# C_ID_5b9c7f6a4b
# C_ID_e4e3953771
# C_ID_f1ffae6fb2
# C_ID_a4ff911a5b
# C_ID_2ecc8b9e3f
# C_ID_5392e911ab
# ...

# %%
train[train.card_id == 'C_ID_8186f3fcc1']
# Out:
#    first_active_month          card_id  feature_1  feature_2  feature_3  \
# 64            2017-09  C_ID_8186f3fcc1          3          1          1
#
#        target
# 64 -33.219281

# %%
train[train.target < -30]
# Out:
#        first_active_month          card_id  feature_1  feature_2  feature_3  \
# 64                2017-09  C_ID_8186f3fcc1          3          1          1
# 92                2015-05  C_ID_b9379a30ea          3          3          1
# 125               2015-10  C_ID_e9120f535c          3          3          1
# 151               2017-03  C_ID_65715cb80d          4          2          0
# 225               2017-01  C_ID_ae77d244b6          2          1          0
# 248               2015-07  C_ID_c4262c902e          5          1          1
# 254               2017-03  C_ID_6a2c823e5f          2          1          0
# 386               2017-06  C_ID_98e1cb10b6          2          3          0
# 467               2017-03  C_ID_eb8175721a          4          1          0
# 515               2016-04  C_ID_a2580006bf          4          2          0
# 566               2016-12  C_ID_2e49ece8b1          2          3          0
# ...

# %%
card_id = 'C_ID_8186f3fcc1'

# %%
history.loc[card_id].sort_values('purchase_date')
# Out:
#                 authorized_flag  city_id category_1  installments category_3  \
# card_id
# C_ID_8186f3fcc1               Y      304          N             1          B
# C_ID_8186f3fcc1               Y       69          N             1          B
# C_ID_8186f3fcc1               Y      304          N             1          B
# C_ID_8186f3fcc1               Y      149          N             1          B
# C_ID_8186f3fcc1               Y      149          N             1          B
# C_ID_8186f3fcc1               Y      149          N             1          B
# C_ID_8186f3fcc1               Y       -1          Y             1          B
# C_ID_8186f3fcc1               Y       -1          Y             1          B
# C_ID_8186f3fcc1               Y      149          N             1          B
# C_ID_8186f3fcc1               Y      149          N             1          B
# C_ID_8186f3fcc1               Y      149          N             1          B
# ...

# %%
new_history.loc[card_id].sort_values('purchase_date')
# Out:
#                 authorized_flag  city_id category_1  installments category_3  \
# card_id
# C_ID_8186f3fcc1               Y      149          N             1          B
# C_ID_8186f3fcc1               Y      149          N             1          B
# C_ID_8186f3fcc1               Y      149          N             1          B
# C_ID_8186f3fcc1               Y      149          N             1          B
# C_ID_8186f3fcc1               Y      149          N             1          B
# C_ID_8186f3fcc1               Y      288          N             1          B
# C_ID_8186f3fcc1               Y      288          N             1          B
# C_ID_8186f3fcc1               Y      288          N             1          B
# C_ID_8186f3fcc1               Y       56          N             1          B
# C_ID_8186f3fcc1               Y      149          N             1          B
# C_ID_8186f3fcc1               Y      149          N             1          B
# ...

# %%
new_history.month_lag.value_counts()
# Out:
# 1    1027617
# 2     935414
# Name: month_lag, dtype: int64
