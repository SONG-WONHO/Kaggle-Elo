# %%
import numpy as np
import pandas as pd

train = pd.read_csv('./data/train.csv')
merchants = pd.read_csv('./data/merchants.csv')
new_merchant_transactions = pd.read_csv('./data/new_merchant_transactions.csv')

# %%
new_merchant_transactions.head()
# Out:
#   authorized_flag          card_id  city_id category_1  installments  \
# 0               Y  C_ID_415bb3a509      107          N             1
# 1               Y  C_ID_415bb3a509      140          N             1
# 2               Y  C_ID_415bb3a509      330          N             1
# 3               Y  C_ID_415bb3a509       -1          Y             1
# 4               Y  C_ID_ef55cf8d4b       -1          Y             1
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          B                   307  M_ID_b0c793002c          1
# 1          B                   307  M_ID_88920c89e8          1
# 2          B                   507  M_ID_ad5237ef6b          2
# 3          B                   661  M_ID_9e84cda3b1          1
# 4          B                   166  M_ID_3c86fa3831          1
#
#    purchase_amount        purchase_date  category_2  state_id  subsector_id
# 0        -0.557574  2018-03-11 14:57:36         1.0         9            19
# ...

# %%
new_merchant_transactions['purchase_amount_integer'] = new_merchant_transactions.purchase_amount.apply(lambda x: x == np.round(x))
print(new_merchant_transactions.groupby('purchase_amount_integer')['card_id'].count())
# Out:
# purchase_amount_integer
# False    1963031
# Name: card_id, dtype: int64

# %%
new_merchant_transactions['purchase_amount_new'] = np.round(new_merchant_transactions['purchase_amount'] / 0.00150265118 + 497.06,2)

# %%
new_merchant_transactions
# Out:
#         authorized_flag          card_id  city_id category_1  installments  \
# 0                     Y  C_ID_415bb3a509      107          N             1
# 1                     Y  C_ID_415bb3a509      140          N             1
# 2                     Y  C_ID_415bb3a509      330          N             1
# 3                     Y  C_ID_415bb3a509       -1          Y             1
# 4                     Y  C_ID_ef55cf8d4b       -1          Y             1
# 5                     Y  C_ID_ef55cf8d4b      231          N             1
# 6                     Y  C_ID_ef55cf8d4b       69          N             1
# 7                     Y  C_ID_ef55cf8d4b      231          N             1
# 8                     Y  C_ID_ef55cf8d4b       69          N             1
# 9                     Y  C_ID_ef55cf8d4b       69          N             1
# 10                    Y  C_ID_ef55cf8d4b       69          N            -1
# ...

# %%
train['target_new'] = 10**(train['target']*np.log10(2))

# %%
sorted(train.target_new.value_counts().index)
# Out:
# [9.99999999219256e-11,
#  5.005180367955197e-06,
#  5.422390669064139e-06,
#  5.6163998882084105e-06,
#  6.689656805835308e-06,
#  1.7099863211048302e-05,
#  2.07969386207385e-05,
#  2.312566487455326e-05,
#  2.4936412136924225e-05,
#  2.841151227013214e-05,
#  2.8848372977198025e-05,
#  3.0275507097386906e-05,
#  3.941212872822619e-05,
#  4.722550174172219e-05,
#  5.128205140732734e-05,
#  5.240266212440574e-05,
#  5.951554359784732e-05,
#  6.66755566533992e-05,
#  7.775312145503245e-05,
#  8.058602176452065e-05,
#  8.493867446321514e-05,
#  8.901548854563114e-05,
#  8.926180464219537e-05,
#  0.00011046062071663472,
#  0.00012322858898442424,
#  0.00012578616309122192,
#  0.00014905795372817802,
#  0.00018411798254243337,
#  0.00019766752374757816,
#  0.000280135585418565,
#  0.00033233632466739716,
#  0.00033886817920491635,
#  0.000380474071255813,
#  0.0003809523802766212,
#  0.00039079291981842525,
#  0.0003988667626797022,
#  0.0004008674785000578,
#  0.00041842754863061145,
# ...

# %%
np.log2(origin_target + 0.0000000001)
# Out:
# -33.219280948873624

# %%
pow(2, np.log2(0.0000000001))
# Out:
# 9.999999999999993e-11

# %%
sorted(pow(2, train.target).value_counts().index)
# Out:
# [9.999999992192566e-11,
#  5.005180367955196e-06,
#  5.42239066906414e-06,
#  5.616399888208413e-06,
#  6.6896568058353104e-06,
#  1.7099863211048312e-05,
#  2.0796938620738512e-05,
#  2.3125664874553277e-05,
#  2.493641213692425e-05,
#  2.8411512270132143e-05,
#  2.884837297719803e-05,
#  3.0275507097386906e-05,
#  3.941212872822619e-05,
#  4.722550174172216e-05,
#  5.1282051407327364e-05,
#  5.240266212440577e-05,
#  5.951554359784738e-05,
#  6.667555665339925e-05,
#  7.775312145503246e-05,
#  8.058602176452057e-05,
#  8.49386744632151e-05,
#  8.901548854563116e-05,
#  8.926180464219533e-05,
#  0.00011046062071663477,
#  0.0001232285889844243,
#  0.000125786163091222,
#  0.00014905795372817797,
#  0.00018411798254243337,
#  0.00019766752374757827,
#  0.0002801355854185652,
#  0.0003323363246673972,
#  0.00033886817920491635,
#  0.0003804740712558132,
#  0.0003809523802766212,
#  0.00039079291981842525,
#  0.0003988667626797021,
#  0.00040086747850005795,
#  0.0004184275486306116,
# ...

# %%
train[train.target < -30]
# Out:
#        first_active_month          card_id  feature_1  feature_2  feature_3  \
# 64                2017-09  C_ID_8186f3fcc1          3          1          1
# 92                2015-05  C_ID_b9379a30ea          3          3          1
# 125               2015-10  C_ID_e9120f535c          3          3          1
# 151               2017-03  C_ID_65715cb80d          4          2          0
# 225               2017-01  C_ID_ae77d244b6          2          1          0
# 248               2015-07  C_ID_c4262c902e          5          1          1
# 254               2017-03  C_ID_6a2c823e5f          2          1          0
# 386               2017-06  C_ID_98e1cb10b6          2          3          0
# 467               2017-03  C_ID_eb8175721a          4          1          0
# 515               2016-04  C_ID_a2580006bf          4          2          0
# 566               2016-12  C_ID_2e49ece8b1          2          3          0
# ...
